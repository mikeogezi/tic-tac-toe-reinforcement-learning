# %%
import gym
from gym.envs.registration import register
import joblib

from keras.models import Sequential, Model
from keras.layers import Activation, Dense, Flatten, Input
from keras.optimizers import Adam
from rl.agents.dqn import DQNAgent
from rl.memory import SequentialMemory
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
# Out:
# Using TensorFlow backend.

# %%
register(id='TicTacToe-v0', entry_point='envs:TicTacToeEnv')
env = gym.make('TicTacToe-v0')

# %%
def build_model(state_size, num_actions):
  input = Input(shape=(1, state_size))
  x = Flatten()(input)
  x = Dense(256, activation='relu')(x)
  x = Dense(64, activation='relu')(x)
  x = Dense(32, activation='relu')(x)
  output = Dense(num_actions, activation='linear')(x)
  model = Model(inputs=input, outputs=output)
  model.summary()
  return model

memory = SequentialMemory(limit=50000, window_length=1)
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=1.0, value_min=-1.0, value_test=.05, nb_steps=1000)

# %%
model = build_model((env.observation_space).n, (env.action_space).n)
dqn = DQNAgent(model=model, policy=policy, nb_actions=(env.action_space).n, memory=memory)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
# Out:
# WARNING:tensorflow:From /Users/mogezi/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 9)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               2560
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 297
# =================================================================
# Total params: 21,385
# Trainable params: 21,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
dqn.fit(
    env, 
    nb_steps=10000,
    visualize=False
)

# %%
res = dqn.test(env, nb_episodes=100, visualize=True)
res?

# %%
joblib.dump(model, 'model.bin')
# Out:
# ['model.bin']

# %%
_model = joblib.load('model.bin')

env.reset_info()
_dqn = DQNAgent(model=_model, policy=policy, nb_actions=(env.action_space).n, memory=memory)
_dqn.compile(Adam(lr=1e-3), metrics=['mae'])
_dqn.test(env, nb_episodes=100, visualize=True)

print(env.info)
# Out:
# Testing for 100 episodes ...
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Episode 1: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Episode 2: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 3: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Episode 4: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  X
#
# Episode 5: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Episode 6: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Episode 7: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Episode 8: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Episode 9: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  _  X  X
#
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  X  X  X
#
# Episode 10: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 11: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  X  X  X
#
# Episode 12: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Episode 13: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Episode 14: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  X  O
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  O
# 1  O  X  _
# 2  _  X  _
#
# Episode 15: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  O
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  X  _
# 2  X  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  X  O
# 2  X  X  O
#
#    0  1  2
# 0  O  _  _
# 1  _  X  O
# 2  X  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  X  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  X  X  O
#
# Episode 16: reward: 20.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 17: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Episode 18: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  O  X  X
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  O  X  X
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  _
# 2  O  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  _  O  _
# 2  O  X  X
#
#    0  1  2
# 0  O  _  X
# 1  _  O  _
# 2  O  X  X
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  _  O  X
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  O  _  X
# 1  _  O  X
# 2  O  X  X
#
# Episode 19: reward: 20.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Episode 20: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  O  O
# 2  _  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  O  O
# 2  _  X  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  _  O  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  _  O  O
# 2  _  X  _
#
#    0  1  2
# 0  X  X  O
# 1  _  O  O
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  _  O  O
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  _  O  O
# 2  O  X  X
#
# Computer ('O') wins 😔
#
# reward: -5 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  X  X  O
# 1  _  O  O
# 2  O  X  X
#
# Episode 21: reward: -10.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 22: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Episode 23: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  X  O
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  O
# 1  O  X  _
# 2  _  X  _
#
# Episode 24: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Episode 25: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Episode 26: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  O  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  O  X  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  X  _
# 2  O  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  X  O
# 2  O  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  X  O
# 2  O  X  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  X  O
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  X  O  _
# 1  _  X  O
# 2  O  X  X
#
# Episode 27: reward: 20.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 28: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 29: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Episode 30: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  X  X  X
#
# Episode 31: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  O
# 1  _  X  _
# 2  _  X  O
#
# Episode 32: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Episode 33: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Episode 34: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Episode 35: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Episode 36: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Episode 37: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Episode 38: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Episode 39: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 40: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  _  X  _
#
# Episode 41: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 42: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 43: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  _  X  O
#
# Episode 44: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  O
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  _  O
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  _  _  O
# 2  X  X  X
#
# Episode 45: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  X  O
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  O
# 1  _  X  O
# 2  _  X  _
#
# Episode 46: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 47: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  _  X  X
#
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  X  X  X
#
# Episode 48: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  _  X  _
#
# Episode 49: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 50: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  X  X  X
#
# Episode 51: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  O  X  X
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  O  X  X
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  _
# 2  O  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  O  O  _
# 2  O  X  X
#
#    0  1  2
# 0  _  _  X
# 1  O  O  _
# 2  O  X  X
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  O  O  X
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  _  _  X
# 1  O  O  X
# 2  O  X  X
#
# Episode 52: reward: 20.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  X  O
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  O
# 1  _  X  O
# 2  _  X  _
#
# Episode 53: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  _  X  X
#
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  X  X  X
#
# Episode 54: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  _  X  X
#
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  X  X  X
#
# Episode 55: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  O  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  O  X  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  X  _
# 2  O  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  X  _
# 2  O  X  X
#
#    0  1  2
# 0  O  O  _
# 1  _  X  _
# 2  O  X  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
# Learner made invalid move
#    0  1  2
# 0  O  O  _
# 1  _  X  _
# 2  O  X  X
#
# Episode 56: reward: -100.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Episode 57: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Episode 58: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Episode 59: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  _  X  _
#
# Episode 60: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  _  X  _
#
# Episode 61: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 62: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  _
# 2  O  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  _
# 2  O  X  O
#
# Episode 63: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Episode 64: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  O  X  _
#
# Episode 65: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# ...
# 2  _  X  _
#
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Episode 79: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 80: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Episode 81: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 82: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Episode 83: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Episode 84: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Episode 85: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  O  X  X
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  O  X  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  X  _
# 2  O  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  X  _
# 2  O  X  X
#
#    0  1  2
# 0  _  _  O
# 1  O  X  _
# 2  O  X  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  O  X  _
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  X  _  O
# 1  O  X  _
# 2  O  X  X
#
# Episode 86: reward: 20.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  _  X  X
#
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  X  X  X
#
# Episode 87: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Episode 88: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  O  _
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  O  _
# 2  O  X  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  _  O  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  O  O  _
# 2  O  X  _
#
#    0  1  2
# 0  X  X  _
# 1  O  O  _
# 2  O  X  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  X
# 1  O  O  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  X  X  X
# 1  O  O  _
# 2  O  X  _
#
# Episode 89: reward: 20.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  _
#
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Episode 90: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Episode 91: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  O
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  X  _
# 2  X  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  X  _
# 2  X  X  O
#
#    0  1  2
# 0  O  _  O
# 1  _  X  _
# 2  X  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  X  _
# 2  X  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#    0  1  2
# 0  O  X  O
# 1  _  X  _
# 2  X  X  O
#
# Episode 92: reward: 20.000, steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  O  X  _
#
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  X  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  O
# 1  _  X  _
# 2  O  X  _
#
# Episode 93: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  O
#
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  _
# 2  O  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  _
# 2  O  X  O
#
# Episode 94: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Episode 95: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  _  X  O
# 2  O  X  _
#
# Episode 96: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  _  X  X
#
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  X  X  X
#
# Episode 97: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  O  X  _
#
# Episode 98: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  O  X  _
#
# Episode 99: reward: 30.000, steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  _
#
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  X
#
# Episode 100: reward: 30.000, steps: 3
# {'x_wins': 98, 'o_wins': 1, 'draws': 0, 'invalidated_games': 1}

# %%
_dqn.fit(
    env, 
    nb_steps=10000,
    visualize=False
)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  O  _  _
#
#     1/10000 [..............................] - ETA: 2:03 - reward: 0.0000e+00
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  _  _
# 2  O  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  _  O
# 2  O  _  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  _  O
# 2  O  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  O  _  O
# 2  O  _  X
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  _  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  X  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  _  X  _
# 2  _  _  X
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  _  O  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  X  _
# 2  _  O  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  X  _
# 2  _  O  O
#
#     9/10000 [..............................] - ETA: 1:11 - reward: -22.2222
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  X  _
# 2  X  O  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  X  O
# 2  X  O  O
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  X  _
# 2  _  _  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  X  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  X  _
# 2  O  _  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  _  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  O  _
# 2  _  _  X
#
#    18/10000 [..............................] - ETA: 1:04 - reward: -27.7778
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  O  _
# 2  X  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  O  O  _
# 2  X  _  X
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  X  _
# 2  _  _  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  X  _
# 2  _  O  O
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  _  _
# 2  _  _  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  X  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  X  _
# 2  _  _  O
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  X  _
# 2  X  _  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  X  O
# 2  X  _  O
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  X  O
# 2  X  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  O  X  O
# 2  X  X  O
#
#    27/10000 [..............................] - ETA: 1:02 - reward: -25.9259
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  _  O  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  X  O  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  O  _  _
# 2  X  O  _
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  _  X
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  O  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  O
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  _  O
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  O  _  O
# 2  _  X  O
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  X
# 1  O  _  O
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  _  _  _
#
#    40/10000 [..............................] - ETA: 56s - reward: -27.0000
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  O  X
# 2  _  _  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  O  X
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  O  X
# 2  X  _  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  _  X
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  X
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  O  X
# 2  _  _  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  _  O  X
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  O  O  X
# 2  _  _  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  _  X
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  _  X
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  O  X  X
#    50/10000 [..............................] - ETA: 55s - reward: -25.6000
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  O  _
# 2  _  _  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  O  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  X  O  X
# 2  _  _  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  X  O  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  X  O  X
# 2  _  _  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  O
# 2  _  X  O
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  X  O
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  X  X  O
# 2  _  X  O
#
# Computer ('O') wins 😔
#
# reward: -5 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  X
# 2  _  _  _
#
#    59/10000 [..............................] - ETA: 56s - reward: -23.3051
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  _  X
# 2  O  _  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  _
# 2  O  X  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  X
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  X
# 1  _  O  X
# 2  O  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  X
# 1  _  O  X
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#    68/10000 [..............................] - ETA: 56s - reward: -20.9559
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  O  X  O
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  X  _
# 2  O  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  X  X  _
# 2  O  X  O
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  X  X  _
# 2  O  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  X  X  O
# 2  O  X  O
#
# Computer ('O') wins 😔
#
# reward: -5 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  _  _
#
#    76/10000 [..............................] - ETA: 57s - reward: -18.4868
#
# choice: 6
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  _
# 2  _  _  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  O  _
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  X  O  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  X  _  _
# 2  X  O  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  X  _  _
# 2  _  _  _
#
#    85/10000 [..............................] - ETA: 58s - reward: -21.2353
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  X  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  X  _  _
# 2  O  _  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  X  _  X
# 2  O  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  X  _  X
# 2  O  O  _
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  X  _  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  X
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  X
# 2  X  _  _
#
#    92/10000 [..............................] - ETA: 1:00 - reward: -21.7935
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  O  _  X
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  O  _  X
# 2  X  X  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  O
# 1  O  _  X
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  O
# 1  O  O  X
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  O
# 1  O  O  X
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 1 | steps: 5
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  X  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  X  _
# 2  _  X  _
#    97/10000 [..............................] - ETA: 1:02 - reward: -20.5670
#
# choice: 0
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  _  O  _
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  O
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  X  _
# 2  O  X  _
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#   108/10000 [..............................] - ETA: 1:01 - reward: -23.1019
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  _  _  _
# 2  X  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  O  X  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  O  _  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  X  _
# 2  O  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  O  X  _
# 2  O  _  _
#
#   116/10000 [..............................] - ETA: 1:01 - reward: -22.1983
#
# choice: 6
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  O  X  O
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  X  _  _
# 2  O  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  X  _  _
# 2  O  X  O
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  O  X
#
#   124/10000 [..............................] - ETA: 1:01 - reward: -23.1855
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  _  O  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  X  _
# 2  _  O  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  _  X  _
# 2  _  O  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  _  _  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  X
# 2  _  O  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  _  _  X
# 2  _  O  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  _  O  X
# 2  _  O  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  X
# 2  _  _  _
#
#   131/10000 [..............................] - ETA: 1:02 - reward: -22.4809
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  X  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  X  _  X
# 2  _  _  O
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  X
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  X
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  _  X
# 2  _  X  O
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  X
# 1  O  _  X
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  X
# 1  O  _  X
# 2  O  X  O
#
# Computer ('O') wins 😔
#
# reward: -5 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  O  _  _
# 2  _  _  _
#
#   138/10000 [..............................] - ETA: 1:03 - reward: -22.1377
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  O  _  _
# 2  _  X  O
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  X
# 1  O  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  X
# 1  O  O  _
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  _  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  _
#
#   145/10000 [..............................] - ETA: 1:04 - reward: -22.4483
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  O  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  X  O  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  X
# 2  X  O  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  _  _  X
# 2  X  O  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  X
# 1  _  _  X
# 2  X  O  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  O  X
# 1  _  X  X
# 2  X  O  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  O  _
# 2  _  _  _
#
#   151/10000 [..............................] - ETA: 1:04 - reward: -22.0861
#
# choice: 4
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  O  _
# 2  _  _  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  _  O  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  _  O  _
# 2  _  _  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  _  O  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  O  O  _
# 2  X  _  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  O  O  _
# 2  X  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  O  O  _
# 2  X  O  X
#
#   156/10000 [..............................] - ETA: 1:06 - reward: -22.0192
#
# choice: 0
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  _  X
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  X
# 1  _  O  _
# 2  _  _  X
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  X
# 2  _  _  _
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  X
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  X
# 2  _  X  _
#
#   162/10000 [..............................] - ETA: 1:06 - reward: -22.4383
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  X
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  X
# 2  O  X  X
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  O  _  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  O  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  _  _
# 2  O  O  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  _  X  _
# 2  O  O  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  _  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  X  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  X  _
# 2  X  _  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  X  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  X  _
# 2  X  _  O
#
#   170/10000 [..............................] - ETA: 1:06 - reward: -21.7941
#
# choice: 1
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  O
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  _  _
# 2  _  _  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  _  _
# 2  O  _  O
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  _  _
# 2  O  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  _  O
# 2  O  X  O
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  X
# 1  X  _  O
# 2  O  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  X
# 1  X  _  O
# 2  O  X  O
#
#   175/10000 [..............................] - ETA: 1:07 - reward: -21.7429
#
# choice: 1
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#   178/10000 [..............................] - ETA: 1:09 - reward: -21.9382
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#   183/10000 [..............................] - ETA: 1:10 - reward: -21.0109
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  X  _
# 2  X  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  X  O
# 2  X  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  X  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  O
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  _  _
# 2  _  _  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  _  _
# 2  O  _  O
#
#   191/10000 [..............................] - ETA: 1:10 - reward: -20.5497
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  X  _
# 2  O  _  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  X  O
# 2  O  _  O
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  _  X  O
# 2  O  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  _  X  O
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  _
# 2  _  X  X
#
#   198/10000 [..............................] - ETA: 1:10 - reward: -19.5707
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  O  _  X
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  O  _  X
# 2  _  X  X
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  O  _  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  X
# 2  _  _  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  _  _  X
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  O
# 1  O  _  X
# 2  _  _  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#   206/10000 [..............................] - ETA: 1:10 - reward: -20.2670
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  O  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  X  O  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  O
# 2  X  O  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  _
# 1  X  _  O
# 2  X  O  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  _  X  X
#
#   213/10000 [..............................] - ETA: 1:10 - reward: -19.3192
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  O  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  O  _
# 2  _  _  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  O  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  O  _
# 2  _  _  O
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  O  _
# 2  X  _  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  X
# 1  X  O  _
# 2  X  _  O
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
# Learner made invalid move
#   221/10000 [..............................] - ETA: 1:09 - reward: -18.8009
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  _  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  O  X
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  O  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  O  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  X  O  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  X  O  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  O  _  O
# 2  X  O  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  O  _  O
# 2  X  O  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  O
# 1  O  X  O
# 2  X  O  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 1 | steps: 5
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  _  _  O
#
#   227/10000 [..............................] - ETA: 1:10 - reward: -18.2599
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  X  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  X  _
# 2  _  X  O
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#   234/10000 [..............................] - ETA: 1:10 - reward: -17.4573
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  O  _
# 1  _  O  O
# 2  _  X  X
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  _  X  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  O  _
# 2  _  _  _
#
#   240/10000 [..............................] - ETA: 1:10 - reward: -17.3125
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  _  O  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  _  O  O
# 2  _  _  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  X
# 1  _  O  O
# 2  _  _  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 5
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  X
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  X
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  _  X
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  O  _  X
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  O  _  X
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  O  O  X
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  O  O  X
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 1 | steps: 5
#   247/10000 [..............................] - ETA: 1:10 - reward: -16.6599
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  X  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  X  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#   254/10000 [..............................] - ETA: 1:11 - reward: -16.5157
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  X  _  O
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  X  _  _
# 2  X  _  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  X  _  _
# 2  X  _  O
#
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  X  _  _
# 2  X  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  X  O  _
# 2  X  X  O
#
# Computer ('O') wins 😔
#
# reward: -5 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  _
#
#   261/10000 [..............................] - ETA: 1:11 - reward: -16.0153
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  _  O
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  _
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  O
# 2  _  _  _
#
#
#
# choice: 3
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  _  O
# 2  _  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  X  _  O
# 2  O  _  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  X
# 1  X  _  O
# 2  O  _  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  X
# 1  X  _  O
# 2  O  _  O
#
#   266/10000 [..............................] - ETA: 1:11 - reward: -15.6391
#
# choice: 5
# Learner (X's) move
# --------------------
# Learner made invalid move
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  O  _
# 2  _  X  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  X
# 1  O  O  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  X
# 1  O  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  X
# 1  O  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  X
# 1  O  O  _
# 2  O  X  X
#
# Computer ('O') wins 😔
#
# reward: -5 | max_steps: 5 | urgency_inv: 2 | steps: 4
#   271/10000 [..............................] - ETA: 1:12 - reward: -15.7565
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  X
# 1  _  O  O
# 2  _  X  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  _  X
# 1  _  O  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  _  X
# 1  _  O  O
# ...
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  _
# 2  _  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  _
# 2  O  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#   571/10000 [>.............................] - ETA: 1:30 - reward: -7.6182
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#   576/10000 [>.............................] - ETA: 1:30 - reward: -7.4479
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#   581/10000 [>.............................] - ETA: 1:30 - reward: -7.3322
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  O  _
# 2  O  X  _
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  _  O  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  X  X  _
# 1  _  O  _
# 2  O  X  O
#
#   585/10000 [>.............................] - ETA: 1:30 - reward: -7.2308
#
# choice: 2
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  X  X
# 1  _  O  _
# 2  O  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#   590/10000 [>.............................] - ETA: 1:30 - reward: -7.0847
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  O  X  X
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  X  _
# 2  O  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  O
# 1  _  X  _
# 2  O  X  X
#
#
#
# choice: 0
# Learner (X's) move
# --------------------
#    0  1  2
# 0  X  O  O
# 1  _  X  _
# 2  O  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  _  _
# 2  _  X  _
#
#   595/10000 [>.............................] - ETA: 1:30 - reward: -6.9916
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  O  X  _
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  _
#
#   601/10000 [>.............................] - ETA: 1:30 - reward: -6.8220
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  O  X  _
#
#   606/10000 [>.............................] - ETA: 1:30 - reward: -6.6667
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  _
# 2  O  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  _
# 2  O  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  _  _
# 2  X  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  X  _
# 2  X  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  O
# 1  _  X  _
# 2  X  X  O
#
#   611/10000 [>.............................] - ETA: 1:30 - reward: -6.5630
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  O
# 1  _  X  _
# 2  X  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  _
#
#   616/10000 [>.............................] - ETA: 1:30 - reward: -6.4286
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  O
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  _  _
# 1  _  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  O
#
#   622/10000 [>.............................] - ETA: 1:30 - reward: -6.2701
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  _  X  O
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  _
# 2  O  X  O
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  X  _
# 2  O  X  O
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#   628/10000 [>.............................] - ETA: 1:30 - reward: -6.1146
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  O  _
# 1  _  _  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  O  X  _
# 1  _  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#   633/10000 [>.............................] - ETA: 1:30 - reward: -5.9716
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  O
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  _  _  O
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  O
# 2  _  X  _
#
#
#
# choice: 4
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  X  O
# 2  _  X  _
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  O
# 2  _  X  X
#
#   638/10000 [>.............................] - ETA: 1:30 - reward: -5.8777
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  O  _
# 1  _  _  O
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  _  _
# 2  _  X  _
#
#
#
# choice: 1
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  O  _
# 2  _  X  _
#
#   641/10000 [>.............................] - ETA: 1:31 - reward: -5.8034
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  _
# 1  O  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  X  O
# 1  O  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 2 | steps: 4
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#   644/10000 [>.............................] - ETA: 1:32 - reward: -5.7453
#
# choice: 8
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  X
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  _  X  X
#
#
#
# choice: 6
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  O  O  _
# 2  X  X  X
#
# Learner ('X') wins 💪
#
# reward: 10 | max_steps: 5 | urgency_inv: 3 | steps: 3
#
#
# choice: 7
# Learner (X's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  _  _
# 2  _  X  _
#
# Computer (O's) move
# --------------------
#    0  1  2
# 0  _  _  _
# 1  _  O  _
# 2  _  X  _
#
#
#
# choice: 8
# Learner (X's) move
# --------------------
# done, took 6.375 seconds

# %%
_dqn.forward?
[0] * 9
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
_dqn.forward([0, 0, -1, 0, 0, -1, 0, 0, -1])
# Out:
# 8
